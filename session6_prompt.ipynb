# %% [markdown]
# # Session 6 Prompt
#
# Create a Jupyter Notebook where, in separate cells, you define functions that return sin(x) and cos(x).  Use Markdown cells to comment on your Notebook, and describe what each function does. Create a third Python cell that will tabulate sin(x) and cos(x) using these previously defined functions vs. x, where x is tabulated between 0 and 2 with a thousand entries. Write a fourth Python cell that will use a for loop to print out the first 10 values of x, sin(x), and cos(x) in columns.

# %%
import numpy as np

# %%
x = 2.0 #float 1
y = 0.8

# %% [markdown]
# ### Define sin(x) and cos(x)

# %%
print(f"np.sin({x}) = {np.sin(x)}") #define sin(x)
print(f"np.cos({x}) = {np.cos(x)}") #define cos(x)
# Out:
# np.sin(2.0) = 0.9092974268256817
# np.cos(2.0) = -0.4161468365471424

# %% [markdown]
# ### Tabulate sin(x) and cos(x)

# %%
x = np.linspace(0,2 * math.pi,1000)
y = x**2

#Tables using standard
#create list of tuples of size 2 w/ all x and y values
table_data = [(a,b) for a,b in zip(x,y)]


#create table
table_header = ["x", "y"]
python_table = tabulate(table_data, tablefmt="grid", 
	headers=table_header,floatfmt=".3f")

def main():
	print(table_data) #quick look into table_data

#This is not organized. It is just all the tabulated information.

#main
if __name__ == "__main__":
	main()
# Out:
# [(np.float64(0.0), np.float64(0.0)), (np.float64(0.006289474781961547), np.float64(3.955749303293025e-05)), (np.float64(0.012578949563923095), np.float64(0.000158229972131721)), (np.float64(0.018868424345884642), np.float64(0.00035601743729637227)), (np.float64(0.02515789912784619), np.float64(0.000632919888526884)), (np.float64(0.03144737390980774), np.float64(0.0009889373258232562)), (np.float64(0.037736848691769284), np.float64(0.001424069749185489)), (np.float64(0.04402632347373083), np.float64(0.0019383171586135825)), (np.float64(0.05031579825569238), np.float64(0.002531679554107536)), (np.float64(0.056605273037653926), np.float64(0.0032041569356673506)), (np.float64(0.06289474781961547), np.float64(0.003955749303293025)), (np.float64(0.06918422260157703), np.float64(0.004786456656984562)), (np.float64(0.07547369738353857), np.float64(0.005696278996741956)), (np.float64(0.08176317216550011), np.float64(0.006685216322565211)), (np.float64(0.08805264694746166), np.float64(0.007753
# ...

# %% [markdown]
# #### First 10 Values

# %%
#Time to organize the table
python_table = tabulate(table_data, headers=table_header, tablefmt="grid", floatfmt=".4f")

def main():
    # The printing of the values as the table. 
    print(tabulate(table_data[:10], headers=table_header, tablefmt="grid", floatfmt=".4f"))

#Main
if __name__ == "__main__":
    main()
# Out:
# +--------+--------+
# |      x |      y |
# +========+========+
# | 0.0000 | 0.0000 |
# +--------+--------+
# | 0.0063 | 0.0000 |
# +--------+--------+
# | 0.0126 | 0.0002 |
# +--------+--------+
# | 0.0189 | 0.0004 |
# +--------+--------+
# | 0.0252 | 0.0006 |
# +--------+--------+
# | 0.0314 | 0.0010 |
# +--------+--------+
# | 0.0377 | 0.0014 |
# +--------+--------+
# | 0.0440 | 0.0019 |
# +--------+--------+
# | 0.0503 | 0.0025 |
# +--------+--------+
# | 0.0566 | 0.0032 |
# +--------+--------+
