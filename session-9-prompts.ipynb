# %% [markdown]
# # Create a Jupyter notebook,
#
# 1) import matplotlib.
# 2) Use numpy to pull 1000 random numbers distributed uniformly between [0,1].
# 3) Histogram the random numbers into 100 bins, and plot the histogram.
# 4) Label your axes and save the figure as a PDF.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Randoming my data.

n = 1000
x = np.random.random(n) #generate random data, w/ uniform probability b/w 0 and 1

#bin creation
#create histrogram bins (where all the data is stored)

width = 0.5
hist_min = np.floor(min(x)) # take the lowest value of the x, and round that down
hist_max = np.ceil(max(x))+width # take the highest value of x, and round up
bins = np.arange(hist_min,hist_max,width)

plt.hist(data, bins=100, edgecolor='gray') #needs to always be after bin creation 

# Label the axes
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Uniform[0, 1] Random Numbers')

# Save the figure as a PDF

plt.savefig("session-9-prompt.pdf",bbox_inches="tight",dpi=300,facecolor='white')
plt.show()
